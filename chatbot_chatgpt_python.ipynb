# %% [markdown]
# # Preparar o ambiente
# Instalando o pacote do OpenAI para configurar a integração com o Chat GPT e importar as bibliotecas necessárias.

# %%
# !pip install openai

# %% [markdown]
# # Criando uma conta e obtendo a chave da API
#
# Após criar ou acessar sua conta no ChatGPT, se faz necessário gerar a chave da API:
# ![Captura de tela 2026-03-01 164209.png](data:image/png;base64,...)

# %% [markdown]
# Executar a chave de API:

# %%
import openai
openai.api_key = 'chave'

# %% [markdown]
# # Chatbot V.1 - Estrutura e conversação
# Definir a estrutura do chatbot usando a função, o enviar e o receber a resposta do chat.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura de conversação básica
mensagem_usuario = 'Olá, como posso te ajudar?'
resposta_chatgpt = enviar_mensagem(mensagem_usuario)

print(f'Resposta do Chat GPT: {resposta_chatgpt}')

# %% [markdown]
# # Chatbot V.2 - Múltiplas mensagens

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura de conversação de múltiplas mensagens
mensagem1 = 'Olá, como posso ajudar?'
mensagem2 = 'Qual é o seu nome?'
mensagem3 = 'Onde posso encontrar informações sobre o produto?'

resposta1 = enviar_mensagem(mensagem1)
resposta2 = enviar_mensagem(mensagem2)
resposta3 = enviar_mensagem(mensagem3)

print(f'Resposta 1: {resposta1}')
print(f'Resposta 2: {resposta2}')
print(f'Resposta 3: {resposta3}')

# %% [markdown]
# # Chatbot V.3 - Contexto inicial
# Define o contexto inicial de comunicação do chatbot com usuário.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura de conversação com contexto inicial
mensagem_inicial = """
Você: Olá, como posso te ajudar?
Modelo: Eu sou um assistente virtual treinado para responder suas perguntas sobre produtos.
"""
mensagem_usuario = 'Qual é o seu nome?'
conversa_com_contexto = mensagem_inicial + 'Você: ' + mensagem_usuario
resposta = enviar_mensagem(conversa_com_contexto)
print(f'Resposta do Chat GPT: {resposta}')

# %% [markdown]
# # Chatbot V.4 - Controle de Temperatura
# Define o grau de precisão da resposta do chatbot ao usuário.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot com controle de temperatura
def enviar_mensagem(mensagem, temperature): #precisa ser declarada
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7, #influência na precisão da resposta
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura do chatbot com contexto inicial
mensagem_inicial = """
Você: Olá, como posso te ajudar?
Modelo: Eu sou um assistente virtual treinado para responder suas perguntas sobre produtos.
"""
mensagem_usuario = 'Qual é o seu nome?'
resposta = enviar_mensagem(mensagem_usuario, temperature = 0.5)
print(f'Resposta do ChatGPT: {resposta}')

# %% [markdown]
# # Chatbot V5 - com Instruções
# Inclui instruções adicionais ao chatbot.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura do chatbot com contexto inicial + instruções
mensagem_inicial = """
Você: Olá, como posso te ajudar?
Modelo: Eou sou um assistente virtual treinado para responder suas perguntas sobre produtos.
"""
# instruções
instrucao = 'Dê uma resposta detalhada sobre os recursos do produto'
mensagem_usuario = 'Quais são os recursos do produto?'
conversa_com_instrucao = mensagem_inicial + 'Você: ' + mensagem_usuario + '\nInstrução: ' + instrucao
resposta = enviar_mensagem(conversa_com_instrucao)
print(f'Resposta do ChatGPT: {resposta}')

# %% [markdown]
# # Chatbot V.6 - Resposta não satisfatória
# Personaliza o comportamento do chatbot para resposta não esperadas/ satisfatórias.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura do chatbot com resposta não satisfatórias
mensagem_usuario = input('Em que posso ajudar?')
resposta = enviar_mensagem(mensagem_usuario)

if 'Desculpe, não entendi' in resposta: # resposta não satisfatórias
  mensagem_usuario = 'Você pode fornecer mais detalhes?'
  resposta = enviar_mensagem(mensagem_usuario)
print(f'Resposta do ChatGPT: {resposta}')

# %% [markdown]
# # Chatbot V7 - Comandos personalizados
# Inclui comandos personalizados ao chatbot para lidar com outras respostas não previstas/ satisfatórias.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura do chatbot com comandos personalizados
mensagem_usuario = input('Em que posso ajudar?')

if mensagem_usuario.startswith('/'):
  comando = mensagem_usuario[1:]
  if comando == 'ajuda':
    resposta = 'Eu sou um assistente virtual que pode responder suas perguntas sobre produtos. Como posso te ajudar?'
  else:
    resposta = 'Desculpe, não entendi o comando. Por favor, tente novamente'
else:
  resposta = enviar_mensagem(mensagem_usuario)
print(f'Resposta do ChatGPT: {resposta}')

# %% [markdown]
# # Chatbot V8 - integração com outra API e/ou serviço
# Permite a integração do chatbot com outra API ou serviço em que esta gerará a resposta ao usuário.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura de integração com outra API e/ou serviço
def obter_resposta_da_api(pergunta):
  resposta = requests.get(f'https://api.example.com/perguntas?pergunta={pergunta}')
  return resposta.json()['resposta']

mensagem_usuario = 'Qual a capital da França?'
if mensagem_usuario.starrtswitch('/api'):
  pergunta = mensagem_usuario[5:]
  resposta = obter_resposta_da_api(pergunta)
else:
  resposta = enviar_mensagem(mensagem_usuario)
print(f'Resposta do ChatGPT: {resposta}')

# %% [markdown]
# # Chatbot V.9 - Armazerar e recuperar conversas anteriores
# Inclui consultas ao chatbot para gerar suas respostas em menor tempo.

# %%
# Importar a biblioteca OpenAI
import openai

# Acessar a chave de API do ChatGPT
openai.api_key = 'chave'

# Estrutura do chatbot
def enviar_mensagem(mensagem):
  resposta = openai.Completion.create(
    engine='text-davinci-003',
    prompt=mensagem,
    max_tokens=50,
    temperature=0.7,
    n=1,
    stop=None
  )
  return resposta.choices[0].text.strip()

# Estrutura do chatbot para armazerar e recuperar conversas anteriores
conversa_anterior = """
Você: Olá, como posso te ajudar?
Modelo: Eu sou um assistente virtual treinado para responder suas perguntas sobre produtos.
Você: Qual é o seu nome?
Modelo: Meu nome é ChatGPT. Como posso ajudar hoje?
"""
mensagem_usuario = input("Como posso ajudá-lo?")
conversa_atual = conversa_anterior + 'Você: ' + mensagem_usuario

resposta = enviar_mensagem(conversa_atual)
print(f'Resposta do Chat GPT: {resposta}')
